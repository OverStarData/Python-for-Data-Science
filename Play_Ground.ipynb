# %%
print("Hello,Mahmoud")
# Out:
# Hello,Mahmoud

# %%
x = 100000
type(x)
# Out:
# int

# %%
print('a', end=' - ' )
print('b', sep='')
# Out:
# a - b

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
x = 'a'
y = 'b'
z = 'c'

print(x,y,z)
# Out:
# a b c

# %%
round(333.3434)
# Out:
# 333

# %%
pow(2,2)
# Out:
# 4

# %%
abs(-230)
# Out:
# 230

# %%
import numpy as np

# %%
np.sum([1,2,3])
# Out:
# 6
